# %%
import numpy as np 
import netCDF4 as Dataset
import xarray as xr

# %%
url = 'http://www.ncei.noaa.gov/thredds/dodsC/gfs-003-files/201903/20190306/gfs_3_20190306_1200_384.grb2'
ds = xr.open_dataset(url, engine='netcdf4')  # or engine='pydap'

# %%
ds.v-component_of_wind_sigma(lat,lon,reftime,time)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-2596089e6c03> in <module>()
# ----> 1 ds.v-component_of_wind_sigma(12312,123123)
#
# ~/.local/lib/python3.6/site-packages/xarray/core/common.py in __getattr__(self, name)
#     177                     return source[name]
#     178         raise AttributeError("%r object has no attribute %r" %
# --> 179                              (type(self).__name__, name))
#     180
#     181     def __setattr__(self, name, value):
#
# AttributeError: 'Dataset' object has no attribute 'v'

# %%
ds.Absolute_vorticity_isobaric
# Out:
# <xarray.DataArray 'Absolute_vorticity_isobaric' (time: 1, isobaric4: 26, lat: 181, lon: 360)>
# [1694160 values with dtype=float32]
# Coordinates:
#   * lat        (lat) float32 90.0 89.0 88.0 87.0 ... -87.0 -88.0 -89.0 -90.0
#   * lon        (lon) float32 0.0 1.0 2.0 3.0 4.0 ... 356.0 357.0 358.0 359.0
#     reftime    datetime64[ns] ...
#   * time       (time) datetime64[ns] 2019-03-22T12:00:00
#   * isobaric4  (isobaric4) float32 1000.0 2000.0 3000.0 ... 97500.0 100000.0
# Attributes:
#     long_name:                      Absolute vorticity @ Isobaric surface
#     units:                          1/s
#     abbreviation:                   ABSV
#     grid_mapping:                   LatLon_Projection
#     Grib_Variable_Id:               VAR_0-2-10_L100
#     Grib2_Parameter:                [ 0  2 10]
#     Grib2_Parameter_Discipline:     Meteorological products
#     Grib2_Parameter_Category:       Momentum
#     Grib2_Parameter_Name:           Absolute vorticity
# ...

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:                                                                   (altitude_above_msl: 3, depth_below_surface_layer: 4, depth_below_surface_layer_bounds_1: 2, height_above_ground: 1, height_above_ground1: 2, height_above_ground2: 1, height_above_ground3: 3, height_above_ground4: 3, height_above_ground_layer: 1, height_above_ground_layer1: 1, height_above_ground_layer1_bounds_1: 2, height_above_ground_layer_bounds_1: 2, isobaric: 31, isobaric1: 19, isobaric2: 1, isobaric3: 21, isobaric4: 26, isobaric5: 17, lat: 181, lon: 360, potential_vorticity_surface: 2, pressure_difference_layer: 1, pressure_difference_layer1: 1, pressure_difference_layer1_bounds_1: 2, pressure_difference_layer2: 2, pressure_difference_layer2_bounds_1: 2, pressure_difference_layer_bounds_1: 2, sigma: 1, sigma_layer: 4, sigma_layer_bounds_1: 2, time: 1, time1: 1, time1_bounds_1: 2)
# Coordinates:
# ...
