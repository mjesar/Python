# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x=[1,2,3,4,5,6,7]
y=[50,51,52,49,48,47,46]

# %%
    plt.xlabel('Date')
    plt.ylabel('Temperature')
    plt.title('Weather')
plt.plot(x,y,color='green',linewidth=5,linestyle='dotted')
